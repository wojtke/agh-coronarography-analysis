# %%
import pandas as pd

# %%
# %cd data
# Out:
# /root/wojtek/random/corflow/data

# %%
# studyfeedback sheets
gsheetid = "11kja-qSHgX5ufjgUqbly6VMD48u39HGDKBlgenpGEsg"

gsheet_url = f"https://docs.google.com/spreadsheets/d/{gsheetid}/gviz/tq?tqx=out:csv"
df = pd.read_csv(gsheet_url)
df.to_csv("studyfeedback.csv", index=False)

# %%
# imagerejectionfeedback sheets
gsheetid = "1-XOZu5pysk77DyDfJPWZl_x3y_GnpTcFvF1FuUA0cTk"

gsheet_url = f"https://docs.google.com/spreadsheets/d/{gsheetid}/gviz/tq?tqx=out:csv"
df = pd.read_csv(gsheet_url)
df.to_csv("imagerejectionfeedback.csv", index=False)

# %%
# imagefeedback sheets
gsheetid = "1wPjNEdEANdj6HO1wwyrJhtDyshQHUJPIDnkW3Y9aUc4"

gsheet_url = f"https://docs.google.com/spreadsheets/d/{gsheetid}/gviz/tq?tqx=out:csv"
df = pd.read_csv(gsheet_url)
df.to_csv("imagefeedback.csv")

# %%
# image.csv

file_id = '1MnbOiqbGMmej3-nHatQ2naRC2lCXXaVu'
url = f'https://drive.google.com/uc?id={file_id}'
df = pd.read_csv(url, delimiter=";")
df.to_csv("image.csv")

# %%
# study.csv

file_id = '16u5whKCWJo4CHcbXZD-_L2Hzvz9Kx0oO'
url = f'https://drive.google.com/uc?id={file_id}'
df = pd.read_csv(url)
df.to_csv("study.csv")

# %%
# studyrejectionfeedback.csv

file_id = '17BnJey_qx_PddQTAXohb6DW_brN-ZcSp'
url = f'https://drive.google.com/uc?id={file_id}'
df = pd.read_csv(url)
df.to_csv("studyrejectionfeedback.csv")

# %%
# framerejectionfeedback.csv

file_id = '1fBhV2Rm1b7GwWHANpZCcxIDhqjAiq-Kv'
url = f'https://drive.google.com/uc?id={file_id}'
df = pd.read_csv(url)# delimiter=";")
df.to_csv("framerejectionfeedback.csv", index=False)
df
# Out:
#                                        ID                            IMAGE_ID  \
# 0    000cc8ba-e751-4373-87e6-c344cabb7dae  131aedfhs6pnf1fvtvp49mk5l3gmfzrq22
# 1    00378b08-8a66-4892-87c6-a8d4c9ab8c3b  131aedfhs6pnf1fvtvp49mff2plx3rdw22
# 2    007d494a-abbc-454e-8bca-b56267537310  131aedfhs6pnf1fvtvp49mk5xd63iqs422
# 3    009b6b0c-dc60-4d13-a929-9928ae987adc  131aedfhs6pnf1fvtvp49mg85r5ebddd22
# 4    00d4d0c1-1b5d-49a8-8c18-3eeaf2ef6d70  131aedfhs6pnf1fvtvp49ml751m1ft2q22
# ..                                    ...                                 ...
# 893  fee114fe-82f7-4556-98ca-c78a13e3dcd6          13c2ur549vohc0jau2fzmooom1
# 894  fef69012-a8b1-4bff-aa1f-9f8b1a893a88  131aedfhs6pnf1fvtvp49mldwdz989wa22
# 895  ff70fb33-38c4-45fb-9e8b-d0fd092ce8ea  131aedfhs6pnf1fvtvp49mld7mlgrpyp22
# 896  ffa315a0-3fba-4340-bda8-b2fe8b1b32ef  131aedfhs6pnf1fvtvp49jyun5fl4qte22
# 897  ffcc52c7-3cdd-43a3-b811-4dc8bb658f06  131aedfhs6pnf1fvtvp49mj7wcrbevo722
#
# ...

# %%
###

# %%
# !unrar x Frame\ Selection.rar
# !unrar x Series\ Selection.rar

# %%
# !mkdir dicoms
# !mkdir metadata

# %%
# !cp Frame\ Selection/dicoms/* dicoms/
# !cp Series\ Selection/accepted/dicoms/* dicoms/
# !cp Series\ Selection/rejected/dicoms/* dicoms/

# %%
# !cp Frame\ Selection/metadata/* metadata/
# !cp Series\ Selection/accepted/metadata/* metadata/
# !cp Series\ Selection/rejected/metadata/* metadata/

# %%
# !cp Series\ Selection/rejected.csv series_selection_rejected.csv
# !cp Series\ Selection/accepted.csv series_selection_accepted.csv

# %%
# !rm -rf Series\ Selection
# !rm -rf Frame\ Selection
